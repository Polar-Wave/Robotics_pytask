# %%
import numpy as np

# %% [markdown]
# Question 1:

# %%
f = np.array([
    [11,22,33],
    [44,55,66],
    [77,88,99]
])

print("First column:",f[:,0])
print("Last row:",f[2,:])
print(f[0:2,1:3])

# %% [markdown]
# Question 2:

# %%
u = np.array([
    [10,20,30],
    [40,50,60],
    [70,80,90]
])
print("First row:", u[0,:])
print("Second column:",u[:,1])
print(u[1,1])

# %% [markdown]
# Question 3:

# %%
n = np.arange(1,13)
print("(3,4) Array:\n", n.reshape(3,4))
print("(2,6) Array:\n", n.reshape(2,6))
print("(2,3,2) Array:\n", n.reshape(2,3,2))

# %% [markdown]
# Question 4:

# %%
z = np.array([1,2,3])
x = np.array([4,5,6])

print("Addition of both arrays:",z+x)
print("Subtraction of both arrays:",z-x)
print("Multiplication of both arrays:",z*x)
print("Division of both arrays:",z/x)
print("Power of 3 of z:",z**3)
print("Power of 3 of x:",x**3)
print("Square of z:",z**2)
print("Square of x:",x**2)
print("mean of z:",np.mean(z))
print("mean of x:",np.mean(x))

# %% [markdown]
# Question 5:

# %%
o = np.random.randint(1,11, size=10)
print("Random array:", o)

p = np.random.randint(1,10,size=(3,3))
print("Random 3x3 array:\n", p)

# %% [markdown]
# Question 6:

# %%
k = np.random.randint(1,100,size=(2,5))
print("Random 2x5 array:\n", k)

# %% [markdown]
# Question 7:

# %%
# in python list any type of data can be stored and it is allocated in that order of the datatype but in numpy arrays only one type of data can be stored and it results in faster matrix operations

# %% [markdown]
# Question 8:

# %%
a = np.array([1,2,3,4])
print("original type:",a.dtype)

a_f= a.astype(float)

print(a_f)
print("\nnew type:",a_f.dtype)

# %% [markdown]
# Question 9:

# %%
""" dtype is only used to check the datatype of the array and reads the datatype only but
    astype() is used to change the datatype of the array and it creates a new array with the new datatypw """

# %% [markdown]
# Question 10:

# %%
mat = np.random.randint(1,100,size=(3,3))

print("Original matrix:\n", mat)

print("\nShape(rows,columns):", mat.shape)
print("Number of elements:", mat.size)
print("Number of axes:", mat.ndim)
print("Datatype:", mat.dtype)

mat_f = mat.astype(float)
print("\nNew datatype:", mat_f.dtype)
print("New matrix:\n", mat_f)

# %% [markdown]
# Question 11:

# %%
j  = np.array([1,2,3,4])
print(j[:,1])

# since we use a comma in [:,1], it is forced to look for a second dimension even though it does not exist, so it gives error for too many indices, it should be like [1]
